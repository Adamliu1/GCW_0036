# %% [markdown]
# # COMP0036 Group Assignment: BEAT THE BOOKIE
#
# ## Group N

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First we set the path for the dataset folder, to access the dataset.

# %%
cwd = os.getcwd() + '\\Data_Files\\Data_Files'
dirName_trainData = cwd + '\\epl-training.csv'
dirName_testData = cwd + '\\epl-test.csv'

# %% [markdown]
# Load the data into a pandas dataframe

# %%
df_epl_train = pd.read_csv(dirName_trainData)
df_epl_test = pd.read_csv(dirName_testData)

# %%
df_epl_train.head()
# Out:
#        Date  HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  19/08/00  Charlton       Man City   4.0   0.0   H   2.0   0.0   H
# 1  19/08/00   Chelsea       West Ham   4.0   2.0   H   1.0   0.0   H
# 2  19/08/00  Coventry  Middlesbrough   1.0   3.0   A   1.0   1.0   D
# 3  19/08/00     Derby    Southampton   2.0   2.0   D   1.0   2.0   A
# 4  19/08/00     Leeds        Everton   2.0   0.0   H   2.0   0.0   H
#
#             Referee  ...   HST  AST   HC   AC    HF    AF   HY   AY   HR   AR
# 0        Rob Harris  ...  14.0  4.0  6.0  6.0  13.0  12.0  1.0  2.0  0.0  0.0
# 1     Graham Barber  ...  10.0  5.0  7.0  7.0  19.0  14.0  1.0  2.0  0.0  0.0
# 2      Barry Knight  ...   3.0  9.0  8.0  4.0  15.0  21.0  5.0  3.0  1.0  0.0
# 3       Andy D'Urso  ...   4.0  6.0  5.0  8.0  11.0  13.0  1.0  1.0  0.0  0.0
# 4  Dermot Gallagher  ...   8.0  6.0  6.0  4.0  21.0  20.0  1.0  3.0  0.0  0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Now, let's create some basic predictors for a simple ML model. These predictors will consist of Date, HomeTeam and AwayTeam.

# %% [markdown]
# We need to convert the data types of data columns that aren't numeric data such as Date, as ML algorithms only work with numeric data.

# %%
df_epl_train.dtypes
# Out:
# Date         object
# HomeTeam     object
# AwayTeam     object
# FTHG        float64
# FTAG        float64
# FTR          object
# HTHG        float64
# HTAG        float64
# HTR          object
# Referee      object
# HS          float64
# AS          float64
# HST         float64
# AST         float64
# HC          float64
# AC          float64
# HF          float64
# AF          float64
# HY          float64
# AY          float64
# HR          float64
# AR          float64
# dtype: object

# %% [markdown]
# The following code overwrites the existing Date column and converts it into the datetime data type. (https://stackoverflow.com/questions/41495580/python-pandas-dataframe-predict-values-based-on-date)

# %%
df_epl_train['Date'] = pd.to_datetime(df_epl_train['Date'])  
df_epl_train['date_delta'] = (df_epl_train['Date'] - df_epl_train['Date'].min())  / np.timedelta64(1,'D')

# %%
df_epl_train["ht_code"] = df_epl_train["HomeTeam"].astype("category").cat.codes

# %%
df_epl_train["at_code"] = df_epl_train["AwayTeam"].astype("category").cat.codes

# %% [markdown]
# Our target for the ML model is what we are trying to predict thus the FTR, so we convert it into codes: H = 2, A = 1 & D = 0.

# %%
df_epl_train["target"] = df_epl_train["FTR"].astype("category").cat.codes

# %%
df_epl_train.head()
# Out:
#         Date  HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0 2000-08-19  Charlton       Man City   4.0   0.0   H   2.0   0.0   H
# 1 2000-08-19   Chelsea       West Ham   4.0   2.0   H   1.0   0.0   H
# 2 2000-08-19  Coventry  Middlesbrough   1.0   3.0   A   1.0   1.0   D
# 3 2000-08-19     Derby    Southampton   2.0   2.0   D   1.0   2.0   A
# 4 2000-08-19     Leeds        Everton   2.0   0.0   H   2.0   0.0   H
#
#             Referee  ...    HF    AF   HY   AY   HR   AR  date_delta  ht_code  \
# 0        Rob Harris  ...  13.0  12.0  1.0  2.0  0.0  0.0       222.0       12
# 1     Graham Barber  ...  19.0  14.0  1.0  2.0  0.0  0.0       222.0       13
# 2      Barry Knight  ...  15.0  21.0  5.0  3.0  1.0  0.0       222.0       14
# 3       Andy D'Urso  ...  11.0  13.0  1.0  1.0  0.0  0.0       222.0       16
# 4  Dermot Gallagher  ...  21.0  20.0  1.0  3.0  0.0  0.0       222.0       22
#
#    at_code  target
# 0       25       2
# 1       42       2
# 2       27       0
# 3       35       1
# 4       17       2
#
# [5 rows x 26 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
count_nan = df_epl_train['date_delta'].isnull().sum()
 
# printing the number of values present
# in the column
print('Number of NaN values present: ' + str(count_nan))
# Out:
# Number of NaN values present: 1

# %%
df_epl_train[df_epl_train['Date'].isnull()]
# Out:
#      Date HomeTeam AwayTeam  FTHG  FTAG  FTR  HTHG  HTAG  HTR Referee  ...  \
# 5700  NaT      NaN      NaN   NaN   NaN  NaN   NaN   NaN  NaN     NaN  ...
#
#       HF  AF  HY  AY  HR  AR  date_delta  ht_code  at_code  target
# 5700 NaN NaN NaN NaN NaN NaN         NaN       -1       -1      -1
#
# [1 rows x 26 columns]
